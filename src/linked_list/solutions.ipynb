# %%
from typing import List, Tuple, Dict, Any, Optional

# %% [markdown]
# ### Reverse linked list
# Given the head of a singly linked list, reverse the list, and return the reversed list.
#
#
#
# Example 1:\
# Input: head = [1,2,3,4,5]\
# Output: [5,4,3,2,1]
#
# Example 2:\
# Input: head = [1,2]\
# Output: [2,1]
#
# Example 3:\
# Input: head = []\
# Output: []

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        prev = None
        curr = head

        while curr:
            next_node = curr.next
            curr.next = prev
            prev = curr
            curr = next_node

        return prev

# %%
sol = Solution()
print(sol.reverseList(ListNode(1, ListNode(2, ListNode(3, ListNode(4, ListNode(5)))))))

# %% [markdown]
# #### Sort Append linked list
#
# You are given the heads of two sorted linked lists list1 and list2.
#
# Merge the two lists into one sorted list. The list should be made by splicing together the nodes of the first two lists.
#
# Return the head of the merged linked list.
#
#
#
# Example 1:
#
#
# Input: list1 = [1,2,4], list2 = [1,3,4]
# Output: [1,1,2,3,4,4]
# Example 2:
#
# Input: list1 = [], list2 = []
# Output: []
# Example 3:
#
# Input: list1 = [], list2 = [0]
# Output: [0]

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution:
    """
    Merge two sorted linked lists and return it as a sorted list. The list should be made by splicing together the nodes of the first two lists.
    """

    def mergeTwoLists(
        self, list1: Optional[ListNode], list2: Optional[ListNode]
    ) -> Optional[ListNode]:
        dummy_node = ListNode()
        curr = dummy_node

        while list1 and list2:
            if list1.val > list2.val:
                curr.next = list2
                list2 = list2.next
            else:
                curr.next = list1
                list1 = list1.next

            curr = curr.next

        if list1:
            curr.next = list1
        else:
            curr.next = list2

        return dummy_node.next

# %%
solution = Solution()
print(
    solution.mergeTwoLists(
        ListNode(1, ListNode(2, ListNode(4))), ListNode(1, ListNode(3, ListNode(4)))
    )
)

# %% [markdown]
# ### Design Singly Linked List
# Design a Singly Linked List class.
#
# Your LinkedList class should support the following operations:
#
# LinkedList() will initialize an empty linked list.\
# int get(int i) will return the value of the ith node (0-indexed). If the index is out of bounds, return -1.\
# void insertHead(int val) will insert a node with val at the head of the list.\
# void insertTail(int val) will insert a node with val at the tail of the list.\
# bool remove(int i) will remove the ith node (0-indexed). If the index is out of bounds, return false, otherwise return true.\
# int[] getValues() return an array of all the values in the linked list, ordered from head to tail.\
# Example 1:
#
# Input:
# ["insertHead", 1, "insertTail", 2, "insertHead", 0, "remove", 1, "getValues"]
#
# Output:
# [null, null, null, true, [0, 2]]
# Example 2:
#
# Input:
# ["insertHead", 1, "insertHead", 2, "get", 5]
#
# Output:
# [null, null, -1]
# Note:
#
# The index int i provided to get(int i) and remove(int i) is guaranteed to be greater than or equal to 0.

# %%
class ListNode:
    """
    Definition for singly-linked list.
    """

    def __init__(self, val, next=None):
        self.val = val
        self.next = next

# %%
from typing import List


class LinkedList:
    """
    Implement a singly linked list with the following methods:
    - get(index: int) -> int: Get the value of the index-th node in the linked list. If the index is invalid, return -1.
    - insertHead(val: int) -> None: Add a node of value val before the first element of the linked list. After the insertion, the new node will be the first node of the linked list.
    - insertTail(val: int) -> None: Append a node of value val as the last element of the linked list.
    - remove(index: int) -> bool: Remove the index-th node in the linked list, if the index is valid.
    - getValues() -> List[int]: Get all values of the linked list in order.
    """

    def __init__(self):
        self.head = ListNode(-1)
        self.tail = self.head

    def get(self, index: int) -> int:
        """
        Get the value of the index-th node in the linked list. If the index is invalid, return -1.
        How to get the value of the index-th node in the linked list is to iterate through the linked list until the index-th node is reached.
        """
        curr = self.head.next
        i = 0

        while curr:
            if i == index:
                return curr.val

            i += 1
            curr = curr.next

        return -1

    def insertHead(self, val: int) -> None:
        """
        What is happening in the insertHead method is that a new node is created with the value val and the next pointer is set to the current head's next node.
        The head's next node is then updated to the new node that was created and if the list was empty before the insertion, the tail is updated to the new node.
        """
        # assign new head
        new_head = ListNode(val)
        new_head.next = self.head.next
        self.head.next = new_head
        if not new_head.next:  # If list was empty before insertion
            self.tail = new_head

    def insertTail(self, val: int) -> None:
        """
        What is happening in the insertTail method is that a new node is created with the value val and the tail's next pointer is set to the new node that was created."
        The tail is then updated to the new node that was created and if the list was empty before the insertion, the head's next node is updated to the new node.
        """

        self.tail.next = ListNode(val)
        self.tail = self.tail.next  # update the tail

    def remove(self, index: int) -> bool:
        """
        The process of removing the index-th node is to iterate through the linked list until the index-th node is reached.
        The previous node's next pointer is then updated to the index-th node's next node.
        """
        i = 0
        curr = self.head

        # find the node before the index-th node to be removed
        while i < index and curr:
            i += 1
            curr = curr.next

        if curr and curr.next:

            if curr.next == self.tail:
                # if the node to be removed is the tail, update the tail
                self.tail = curr

            # remove the node by updating the next pointer of the previous node
            curr.next = curr.next.next
            return True

        return False

    def getValues(self) -> List[int]:
        curr = self.head.next
        values = []

        while curr:
            values.append(curr.val)
            curr = curr.next

        return values

# %%
linked_list = LinkedList()
# insert values at the beginning
linked_list.insertHead(1)
linked_list.insertHead(2)
linked_list.insertHead(3)
# insert values at the end
linked_list.insertTail(4)
linked_list.insertTail(5)

print(linked_list.getValues())
# only get a specific value
print(linked_list.get(2))
print(linked_list.get(3))

# remove a value
print(linked_list.remove(2))
print(linked_list.getValues())
# Out:
# [3, 2, 1, 4, 5]
# 1
# 4
# True
# [3, 2, 4, 5]

# %% [markdown]
# #### Reverse a Linked List
#
# The question is to reverse a singly linked list
#
# Example 1:
#
# Input: 1 -> 2 -> 3 -> 4 -> 5 -> NULL\
# Output: 5 -> 4 -> 3 -> 2 -> 1 -> NULL
#
# Example 2:
#
# Input: 1 -> 2 -> NULL\
# Output: 2 -> 1 -> NULL
#
# Example 3:
#
# Input: NULL\
# Output: NULL

# %% [markdown]
# ### **Reverse a Linked List – A Super Simple Explanation**
#
# Imagine you have a row of **train cars** connected in one direction:
#
# 🚂 **1 → 2 → 3 → NULL**
#
# Now, we want to **reverse the train** so that it looks like this:
#
# 🚂 **3 → 2 → 1 → NULL**
#
# Let's break this down **step by step** with a **simple analogy** so that even a baby can understand.
#
# ---
#
# ### **Step-by-Step Thought Process**
#
# #### **1. The Big Idea – Flipping Connections**
# Each train car (**node**) is connected to the next one. **Our goal is to flip each connection** so that every car points backward instead of forward.
#
# To do this, we need to:
# 1. **Remember the next car** (so we don’t lose it).
# 2. **Break the current connection** and flip it backward.
# 3. **Move to the next car and repeat**.
#
# ---
#
# ### **2. Setting Up Variables**
# We need two hands to help us flip the train cars:
# - **One hand (`node`) holds the reversed train so far.**
# - **One hand (`head`) points to the current car we’re flipping.**
# - We also need a **third hand (`temp`)** to hold the next car so we don't lose it.
#
# Let's start with:
# ```python
# node = None  # The reversed train (empty at first)
# head = first node (1)  # The current car we are processing
# ```
#
# ---
#
# ### **3. Reversing One Connection at a Time**
#
# #### **Step 1: Process Car "1"**
# 🚂 `1 → 2 → 3 → NULL`
#
# - **Store the next car** (`temp = 2`) so we don’t lose it.
# - **Break the connection** and make `1` point to `node` (which is `None` for now).
# - **Move `node` to `1`** because it’s now the head of the reversed train.
# - **Move `head` to `temp (2)`** to process the next car.
#
# **Result after Step 1:**
# 🚂 `1 → NULL` (Reversed so far)
# 🚂 `2 → 3 → NULL` (Original list remaining)
#
# ---
#
# #### **Step 2: Process Car "2"**
# 🚂 `1 → NULL`
# 🚂 `2 → 3 → NULL`
#
# - **Store the next car** (`temp = 3`).
# - **Break the connection** and make `2` point to `1`.
# - **Move `node` to `2`** (new head of reversed train).
# - **Move `head` to `temp (3)`**.
#
# **Result after Step 2:**
# 🚂 `2 → 1 → NULL` (Reversed so far)
# 🚂 `3 → NULL` (Original list remaining)
#
# ---
#
# #### **Step 3: Process Car "3"**
# 🚂 `2 → 1 → NULL`
# 🚂 `3 → NULL`
#
# - **Store the next car** (`temp = NULL`).
# - **Break the connection** and make `3` point to `2`.
# - **Move `node` to `3`** (new head of reversed train).
# - **Move `head` to `temp (NULL)`**, meaning we are done.
#
# **Final Reversed Train:**
# 🚂 `3 → 2 → 1 → NULL` ✅
#
# ---
#
# ### **4. Code Implementation**
# ```python
# class Solution:
#     def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
#         node = None  # This will store the reversed linked list
#
#         while head:  # Keep processing until we run out of nodes
#             temp = head.next  # Step 1: Save the next node
#             head.next = node  # Step 2: Reverse the link
#             node = head       # Step 3: Move node pointer forward
#             head = temp       # Step 4: Move head to next node
#
#         return node  # The new head of the reversed linked list
# ```
#
# ---
#
# ### **5. Complexity Analysis**
# | **Time Complexity** | **Space Complexity** |
# |--------------------|--------------------|
# | **O(n)** → We visit each node once | **O(1)** → No extra space, just pointers |
#
# ---
#
# ### **6. Simple Flow Summary (Baby Version)**
# 1️⃣ **Hold the next train car in `temp`** (so we don’t lose it).
# 2️⃣ **Flip the current train car's connection to the previous car** (`head.next = node`).
# 3️⃣ **Move the `node` pointer forward** (so it remembers the new reversed train).
# 4️⃣ **Move the `head` pointer forward** (to process the next train car).
# 5️⃣ **Repeat until all cars are reversed.**
# 6️⃣ **Return `node` as the new head of the reversed train.**
#
# ---
#
# ### **7. Final Recap**
# 📌 **Think of the problem as flipping train cars one by one.**
# 📌 **We use three pointers (`node`, `head`, `temp`) to carefully reverse the links.**
# 📌 **Time complexity is O(n), and we use no extra space!**
#
# Hope this makes sense! 🚂💡😃

# %%
from typing import List, Tuple, Dict, Any, Optional


class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        node = None

        while head:
            temp = head.next
            head.next = node
            node = head
            head = temp

        return node

# %% [markdown]
# ### Merge Two Sorted Linked Lists
# You are given the heads of two sorted linked lists list1 and list2.
#
# Merge the two lists into one sorted linked list and return the head of the new sorted linked list.
#
# The new list should be made up of nodes from list1 and list2.
#
# Example 1:
#
# Input: list1 = [1,2,4], list2 = [1,3,5]
#
# Output: [1,1,2,3,4,5]
#
# Example 2:
#
# Input: list1 = [], list2 = [1,2]
#
# Output: [1,2]
#
# Example 3:
#
# Input: list1 = [], list2 = []
#
# Output: []

# %%
from typing import List, Tuple, Dict, Any, Optional


class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution:
    """Merge two sorted linked lists and return it as a sorted list. The list should be made by splicing together the nodes of the first two lists."""

    def mergeTwoLists(
        self, list1: Optional[ListNode], list2: Optional[ListNode]
    ) -> Optional[ListNode]:
        dummy_node = ListNode()

        curr = dummy_node

        while list1 and list2:

            if list1.val > list2.val:
                curr.next = list2  # append the val
                list2 = list2.next  # update to next node

            else:
                curr.next = list1  # append the val
                list1 = list1.next  # update to next node

            curr = curr.next  # update to next node in the merged list

        curr.next = list1 or list2  # append the remaining list to the merged list

        return dummy_node.next

# %%
solution = Solution()
print(
    solution.mergeTwoLists(
        ListNode(1, ListNode(2, ListNode(4))), ListNode(1, ListNode(3, ListNode(4)))
    )
)
